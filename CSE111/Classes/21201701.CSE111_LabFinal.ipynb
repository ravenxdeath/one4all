# %%
#Name: Md. Tahmid Iqbal
#ID: 21201701
#WRITE YOUR CODE HERE

class Ride:
    def __init__(self,name,description="water",capacity=15, fare=5):
        self.name = name
        self.description = description
        self.__capacity = capacity
        self.__fare = fare
        # self.onboard = 0
        
        print (f"{self.name} is a {self.description} ride that has a total capacity of {self.__capacity} and costs {self.__fare}tk")
    def setCapacity(self, newcap):
        self.__capacity = newcap  
   
    def getCapacity(self):
        return self.__capacity 
    def getFare(self):
        return self.__fare 
    # def printDetails(self):
    #     print(f"{self.name} is a {self.description} ride that has a total capacity of {self.capacity} and costs {self.fare}tk")
    def displayRides(self):
        print(f"Basic is a water ride that costs 5tk\nTea cup is a dry ride that costs 10tkSwing is a dry ride that costs 5tk\nPaddle boat is a water ride that costs 5tk
Canoe is a water ride that costs 5tk
Hoky poky is a dry ride that costs 10tk
Pegasus is a dry ride that costs 10tk")
        
class RollerCoaster(Ride):
    def __init__(self, name, fare, speed):
        super().__init__(name, "dry", 25, fare)
        self.speed = speed
        self.onboard = 0

        print(f"New Rollercoaster named {self.name} created. It has a capacity of {super().getCapacity()} and it's fare is {super().getFare()}tk. It moves at a speed of {self.speed} m/s")

    def boardRide(self, x):
        self.onboard = x
        if self.onboard > super().getCapacity():
            print(f"Can't board over capacity.")
        elif self.onboard == super().getCapacity:
            print(f"25 people on board!\nRide has begun! Hang on tight!\nRide has ended! Hope you had fun!")
            self.onboard = 0
        
        elif self.onboard < super().getCapacity():
        
            print(f"{self.onboard} people on board!\nRide is waiting for full capacity to be reached.")
        

basic_ride = Ride('Basic')
tea_cup = Ride("Tea cup", "dry", 2, 10)
Swing = Ride("Swing", "dry", 3)
paddle_boat = Ride("Paddle boat")
canoe_boat = Ride("Canoe")

print(basic_ride)
print('_____________')
print(tea_cup)
print('_____________')
print(Swing)
print('_____________')

RC1 = RollerCoaster("Hoky poky", 10, 60)
print('_____________')
RC1.boardRide(5)
print('_____________')
RC1.boardRide(35)
print('_____________')
RC1.boardRide(20)
print('_____________')
RC1.boardRide(2)
print('_____________')
RC1.boardRide(18)
print('_____________')
RC1.boardRide(7)
print('_____________')
RC1.boardRide(5)
print('_____________')
RC1.boardRide(20)
print('_____________')

RC2 = RollerCoaster("Pegasus", 10, 70)
print('_____________')
RC2.setCapacity(5)
print('_____________')
Ride.displayRides()
print('_____________')
# Out:
# Basic is a water ride that has a total capacity of 15 and costs 5tk
# Tea cup is a dry ride that has a total capacity of 2 and costs 10tk
# Swing is a dry ride that has a total capacity of 3 and costs 5tk
# Paddle boat is a water ride that has a total capacity of 15 and costs 5tk
# Canoe is a water ride that has a total capacity of 15 and costs 5tk
# ...
# _____________
# ...
# _____________
# ...
# _____________
# Hoky poky is a dry ride that has a total capacity of 25 and costs 10tk
# New Rollercoaster named Hoky poky created. It has a capacity of 25 and it's fare is 10tk. It moves at a speed of 60 m/s
# _____________
# 5 people on board!
# Ride is waiting for full capacity to be reached.
# _____________
# Can't board over capacity.
# _____________
# 20 people on board!
# Ride is waiting for full capacity to be reached.
# _____________
# 2 people on board!
# Ride is waiting for full capacity to be reached.
# _____________
# 18 people on board!
# Ride is waiting for full capacity to be reached.
# ...

# %%
class A:
    temp = 4
    a = [1]
    
    def __init__(self):
        self.sum = 0
        self.y = 0
        self.y = A.temp - 2 + A.a[0]
        self.sum = A.temp + 1
        A.temp -= 2
        
    def methodA(self, m, n):
        x = 0 
        self.y = self.y +m +(A.temp)
        A.temp += A.a[0]
        x = x+1+n
        A.a[0] -= 1
        self.sum = self.sum + x +self.y
        print(x, self.y, self.sum)
class B(A):
    x = 0 
    def __init__(self, b = None):
        self.y = 12
        self.sum = 3
        if b == None:
            super().__init__()
            self.y = A.temp + 3
            self.sum = self.sum +3 + A.temp
        
        else:
            B.x = b.x+A.a[0]
            self.sum = b.sum + A.temp + 6
            self.y += B.x
        
    def methodB(self, m, n):
        y = 7+ m
        B.x = self.y + 2+ A.temp
        y = y + self.y
        self.methodA(B.x, y)
        self.sum =  B.x + y + self.sum      
        print(B.x, y, self.sum)
        B.x -=1
        
a1 = A()
b1 = B()
b2 = B(b1)
b1.methodA(1,2)
b2.methodB(3,2)
# Out:
# 3 4 13
# 24 30 66
# 16 23 105
