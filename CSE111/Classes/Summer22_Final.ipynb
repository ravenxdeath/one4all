# %% [markdown]
# Question 1: CO4 [10 Points]
#
# Design the Monster class with necessary properties so that the given output is produced.
# [Hint:
# 1. Let's say there are 2 monsters: A and B.
# -A can attack B if A is alive.
# -If A is alive, it can only attack B if B is alive.
# -If A's power is greater than that of B, only then A can defeat B;
# Otherwise, A will be defeated by B.
# - Once a monster gets defeated, it is considered to be dead.
# 2. The variable "monsterCount" keeps track of the number of monsters
# alive. So, update it accordingly.]

# %%
# class Monster:
#   monsterCount = 0
#   def __init__(self,name,power):
#     self.name = name
#     self.power = power
#     self.alive = True
#     Monster.monsterCount += 1
#   def get_details(self):
#     if self.alive == True:
#       return(f'Name: {self.name}\nPower: {self.power}\nAlive: {self.alive}')
#     else:
#       return(f'Name: {self.name}\nPower: {self.power}\nAlive: False')

#   def attack (self,*args):
#     if len(args) == 0:
#       print('No monsters to attack')
#     elif len(args) == 1:
#         if args[0].alive == True and self.alive ==True:
#             if args[0].power > self.power:
#                 self.alive = False
#                 Monster.monsterCount -= 1
#                 print(f"Attack unsuccessful {args[0].name} was defeated by {self.name}")
#             else:
#                 args[0].alive = False
#                 Monster.monsterCount -= 1
#                 print(f"Attack successful {self.name} defeated {args[0].name}")
#         elif args[0].alive == False and self.alive == True:
#             print(f"{args[0].name} is not alive to attack")
#         elif args[0].alive == True and self.alive == False:
#             print(f"cannot attack {self.name}. It's not alive.")
#     elif len(args) == 2:
#         for i in range(len(args)):
#             if args[i].alive == True and self.alive ==True:
#                 if args[i].power > self.power:
#                     self.alive = False
#                     Monster.monsterCount -= 1
#                     print(f"Attack unsuccessful {args[i].name} was defeated by {self.name}")
#                 else:
#                     args[i].alive = False
#                     Monster.monsterCount -= 1
#                     print(f"Attack successful {self.name} defeated {args[i].name}")
#             elif args[i].alive == False and self.alive == True:
#                 print(f"{args[i].name} is not alive to attack")
#             elif args[i].alive == True and self.alive == False:
#                 print(f"cannot attack {self.name}. It's not alive.")
        
# monster1 = Monster('Godzilla', 40)
# monster2 = Monster('Hydra', 30)
# monster3 = Monster('KingKong', 50)
# print(f"Number of monsters alive:{Monster.monsterCount}")
# print('1--------------------------------')
# print(monster1.get_details())
# print('2--------------------------------')
# print(monster2.get_details())
# print('3--------------------------------')
# print(monster3.get_details())
# print('4--------------------------------')
# monster1.attack()
# print('5--------------------------------')
# monster1.attack(monster2)
# print('6--------------------------------')
# monster1.attack(monster2, monster3)
# print('7--------------------------------')
# print(f"Number of monsters alive:{Monster.monsterCount}")
# print('8--------------------------------')
# print(monster2.get_details())
# print('9--------------------------------')
# monster2.attack(monster1)
# Out:
# Number of monsters alive:3
# 1--------------------------------
# Name: Godzilla
# Power: 40
# Alive: True
# 2--------------------------------
# Name: Hydra
# Power: 30
# Alive: True
# 3--------------------------------
# Name: KingKong
# Power: 50
# Alive: True
# 4--------------------------------
# No monsters to attack
# 5--------------------------------
# Attack successful Godzilla defeated Hydra
# 6--------------------------------
# Hydra is not alive to attack
# Attack unsuccessful KingKong was defeated by Godzilla
# 7--------------------------------
# Number of monsters alive:1
# 8--------------------------------
# Name: Hydra
# Power: 30
# Alive: False
# 9--------------------------------

# %%
class Monster:
    monsterCount = 0
    def __init__(self, name, power,stat=True):
        self.__name = name
        self.__power = power
        self.__stat = stat
        Monster.monsterCount += 1  
        
    def get_details(self):
        return f"Name: {self.__name}\nPower: {self.__power}\nAlive: {self.__stat}"

    
    def attack(self, *args):
        if len(args) == 0:
            print(f"No monsters to attack")
        # elif len(args) == 1:
        #     if args[0].__stat == True and self.__stat ==True:
        #         if  self.__power > args[0].__power:
        #             args[0].__stat = False
        #             print(f"Attack successful.{self.__name} defeated {args[0].__name}.")
        #             Monster.monsterCount -= 1
        #         else:
        #             self.__stat = False
        #             print(f"Attack unsuccessful. {self.__name} was defeated by {args[0].__name}.")
        #             Monster.monsterCount -= 1
        #     elif args[0].__stat == False and self.__stat == True:
        #         print(f"{args[0].__name} is not alive to attack.")
        #     elif args[0].__stat == True and self.__stat == False:
        #         print(f"cannot attack {self.__name}. It's not alive.")
                
        else:
            for i in range(len(args)):
                if args[i].__stat == True and self.__stat ==True:
                    if  self.__power > args[i].__power:
                        args[i].__stat = False
                        print(f"Attack successful.{self.__name} defeated {args[i].__name}.")
                        Monster.monsterCount -= 1
                    else:
                        self.__stat = False
                        print(f"Attack unsuccessful. {self.__name} was defeated by {args[i].__name}.")
                        Monster.monsterCount -= 1
                elif args[i].__stat == True and self.__stat == False:
                    print(f"cannot attack {self.__name}. It's not alive.")
                elif args[i].__stat == False and self.__stat == True:
                    print(f"{args[i].__name} is not Alive to attack")              
            
#Write your code here
monster1 = Monster('Godzilla', 40)
monster2 = Monster('Hydra', 30)
monster3 = Monster('KingKong', 50)
print(f"Number of monsters alive:{Monster.monsterCount}")
print('1--------------------------------')
print(monster1.get_details())
print('2--------------------------------')
print(monster2.get_details())
print('3--------------------------------')
print(monster3.get_details())
print('4--------------------------------')
monster1.attack()
print('5--------------------------------')
monster1.attack(monster2)
print('6--------------------------------')
monster1.attack(monster2, monster3)
print('7--------------------------------')
print(f"Number of monsters alive:{Monster.monsterCount}")
print('8--------------------------------')
print(monster2.get_details())
print('9--------------------------------')
monster2.attack(monster1)
# Out:
# Number of monsters alive:3
# 1--------------------------------
# Name: Godzilla
# Power: 40
# Alive: True
# 2--------------------------------
# Name: Hydra
# Power: 30
# Alive: True
# 3--------------------------------
# Name: KingKong
# Power: 50
# Alive: True
# 4--------------------------------
# No monsters to attack
# 5--------------------------------
# Attack successful.Godzilla defeated Hydra.
# 6--------------------------------
# Hydra is not Alive to attack
# Attack unsuccessful. Godzilla was defeated by KingKong.
# 7--------------------------------
# Number of monsters alive:1
# 8--------------------------------
# Name: Hydra
# Power: 30
# Alive: False
# 9--------------------------------

# %%
# with a different approach tho it doesn't work on two parameters 
#! will work but with more implementations 
class Monster:
    monsterCount = 0
    def __init__(self, name, power,stat=True):
        self.__name = name
        self.__power = power
        self.__stat = stat
        Monster.monsterCount += 1  
        ls = [] 
        
    def get_details(self):
        return f"Name: {self.__name}\nPower: {self.__power}\nAlive: {self.__stat}"
        
    def attack(self, kaijuu=None, kaijuu1=None, kaijuu2=None):
        
        
        if kaijuu == None and kaijuu1 == None and kaijuu2 == None:
            print(f"No monsters to attack")
            
        elif kaijuu1 == None and kaijuu2 == None:
            if self.__power > kaijuu.__power and kaijuu.__power == 0:
                print(f"{kaijuu.__name} is not alive to attack.")
            elif self.__power > kaijuu.__power and kaijuu.__power > 0:
                print(f"Attack successful. {self.__name} defeated {kaijuu.__name}.")
                kaijuu.__power = 0
                kaijuu.__stat = False
                Monster.monsterCount -= 1  
            elif self.__power < kaijuu.__power and kaijuu.__power > 0:
                print(f"Attack unsuccessful. {self.__name} was defeated by {kaijuu.__name}.")
                
        elif kaijuu2 == None:
            #! For driver code's monster 2 or parameter kaijuu 
            if self.__power > kaijuu.__power and kaijuu.__power == 0:
                print(f"Cannot attack {kaijuu.__name}. It's not alive.")
            elif self.__power > kaijuu.__power and kaijuu.__power > 0:
                print(f"Attack successful. {self.__name} defeated {kaijuu.__name}.")
                kaijuu.__power = 0
                kaijuu.__stat = False
                Monster.monsterCount -= 1  
            elif self.__power < kaijuu.__power and kaijuu.__power > 0:
                print(f"Attack unsuccessful. {self.__name} was defeated by {kaijuu.__name}.")
                
            #! For driver code's monster 3 or parameter kaijuu1
            elif self.__power > kaijuu1.__power and kaijuu1.__power == 0:
                print(f"Cannot attack {kaijuu1.__name}. It's not alive to attack.")            
            elif self.__power > kaijuu1.__power and kaijuu1.__power > 0:
                print(f"Attack successful. {self.__name} defeated {kaijuu1.__name}.")
                kaijuu1.__power = 0
                kaijuu1.__stat = False
                Monster.monsterCount -= 1  
            elif self.__power < kaijuu1.__power and kaijuu1.__power > 0:
                print(f"Attack unsuccessful. {self.__name} was defeated by {kaijuu1.__name}.")

            
            
#Write your code here
monster1 = Monster('Godzilla', 40)
monster2 = Monster('Hydra', 30)
monster3 = Monster('KingKong', 50)
print(f"Number of monsters alive:{Monster.monsterCount}")
print('1--------------------------------')
print(monster1.get_details())
print('2--------------------------------')
print(monster2.get_details())
print('3--------------------------------')
print(monster3.get_details())
print('4--------------------------------')
monster1.attack()
print('5--------------------------------')
monster1.attack(monster2)
print('6--------------------------------')
monster1.attack(monster2, monster3)
print('7--------------------------------')
print(f"Number of monsters alive:{Monster.monsterCount}")
print('8--------------------------------')
print(monster2.get_details())
print('9--------------------------------')
monster2.attack(monster1)
# Out:
# Number of monsters alive:3
# 1--------------------------------
# Name: Godzilla
# Power: 40
# Alive: True
# 2--------------------------------
# Name: Hydra
# Power: 30
# Alive: True
# 3--------------------------------
# Name: KingKong
# Power: 50
# Alive: True
# 4--------------------------------
# No monsters to attack
# 5--------------------------------
# Attack successful. Godzilla defeated Hydra.
# 6--------------------------------
# Cannot attack Hydra. It's not alive.
# Attack unsuccessful. Godzilla was defeated by KingKong.
# 7--------------------------------
# Number of monsters alive:2
# 8--------------------------------
# Name: Hydra
# Power: 0
# Alive: False
# 9--------------------------------
# Attack unsuccessful. Hydra was defeated by Godzilla.

# %% [markdown]
# Question 2: CO5 [10 Points]
#
# Implement the BracbookUser class that is derived from the User class with necessary
# properties so that the given output is produced.
# [You are not allowed to change the given code under any circumstances.]

# %%
#Driver Code
class User:
    activities = ["Post", "Like", "Comment"]
    def __init__(self, name,email):
        self.name = name
        self.email = email
    def UserActivity(self, activityType):
        if activityType in User.activities:
            return True
        else:
            return False
    def userDetail(self):
        return f"User Detail:\nName:{self.name}\nEmail: {self.email}"

class BracbookUser(User):
    def __init__(self, name, email, number=None):
        super().__init__(name, email)
        self.number = number
    
    def UserActivity(self, activityType):
        return super().UserActivity(activityType)
    
    def userDetail(self):
        return super().userDetail()
        if self.number == None:
            print(F"Phone: Not set")
        else:
            print(f"Phone: {self.number}")
#Write your code here
user1 = BracbookUser("Rakait","xyz@gmail.com")
print("1===========================")
print(user1.userDetail())
print("2===========================")
user2 = BracbookUser("Sazzad","abc@gmail.com",
"01727xxxxxx")
print("3===========================")
print(user2.userDetail())
print("4===========================")
user1.UserActivity("Like")
print("5===========================")
user1.UserActivity("Comment")
print("6===========================")
print(user1.userDetail())
print("7===========================")
user2.UserActivity("Share")
print("8===========================")
user2.UserActivity("Comment")
print("9===========================")
print(user2.userDetail())
# Out:
# 1===========================
# User Detail:
# Name:Rakait
# Email: xyz@gmail.com
# 2===========================
# 3===========================
# User Detail:
# Name:Sazzad
# Email: abc@gmail.com
# 4===========================
# 5===========================
# 6===========================
# User Detail:
# Name:Rakait
# Email: xyz@gmail.com
# 7===========================
# 8===========================
# 9===========================
# User Detail:
# Name:Sazzad
# Email: abc@gmail.com

# %%
class A:
    temp = 5
    def __init__(self):
        self.y = A.temp - 2
        self.sum = A.temp + 1
        A.temp += 3
    def methodA(self, m, n):
        x = 0
        self.y = self.y + m + (A.temp)
        x = x + 2 + n
        print(x, self.y, self.sum)
        self.methodB(-2, 6)
        self.sum = self.sum + x + A.temp
        self.methodB(-4, self.sum, 3)
    def methodB(self, m, n):
        y = 5
        y = y + self.y
        self.sum = B.x + y + n
        print(B.x, y, self.sum)
class B(A):
    x = 1
    def __init__(self, obj=None):
        super().__init__()
        if obj != None:
            obj.sum = 11
        self.y = A.temp + 4
        self.sum = 3 + A.temp + B.x
    def methodB(self, m, n, y=0):
        y = y + self.y + n
        B.x = m + self.y + n    
        self.sum = B.x + y + A.temp
        print(B.x, y, self.sum)

b1 = B()
b2 = B(b1)
b1.methodA(-3, -7)
# Out:
# -5 20 11
# 24 26 61
# 83 90 184
